# %%
import pandas as pd
import numpy as np

import os

base_path = '/Users/raynasser/code/raynasser/MediSure/data/raw_data'
foodrug = '/Users/raynasser/code/raynasser/MediSure/data/raw_data/FooDru'

# %%
# # Get the list of files, ignoring folders and selecting only .csv files
# csv_files = [f for f in os.listdir(base_path) if f.endswith('.csv')]

# # Function to run EDA on each dataframe
# def run_eda(df, file_name):
#     display(f"\n--- EDA Report for {file_name} ---")

#     # Display the columns
#     display(f'\nColumns:\n{df.columns}\n')

#     # Shape of the DataFrame
#     display(f"Number of rows: {df.shape[0]:,}")
#     display(f"Number of columns: {df.shape[1]:,}")

#     # Data types of the columns
#     display(f"\nData Types:\n{df.dtypes.unique()}\n")

#     # Count of each data type
#     display(f"Data Types Count:\n{df.dtypes.value_counts()}\n")

#     # Statistical description of the DataFrame
#     display("\nStatistical Description:\n", df.describe(include='all'))  # include='all' to cover both numeric and categorical data

#     # Number of duplicated rows
#     display(f'\nNumber of Duplicates: {df.duplicated().sum():,}')

#     # Missing values count
#     display("\nMissing Values Count:\n", pd.DataFrame(df.isna().sum()))

# # Loop through each CSV file, read it into a DataFrame, and run the EDA pipeline
# for file in csv_files:
#     file_path = os.path.join(base_path, file)

#     # Read CSV into DataFrame
#     df = pd.read_csv(file_path)#, index_col='Unnamed: 0')  # Modify index_col as per your need

#     # Run EDA on the DataFrame
#     run_eda(df, file)

# %%
def eda_pipeline(df):

    print('_' * 33)
    print(f'\n\nColumns:\n{df.columns}\n\n')

    print('_' * 33)
    display(f'Total Rows: {df.shape[0]:,}')

    # # Display the unique data types
    # print('\n\nUnique data types:')
    # print(df.dtypes.unique())

    # # Display the count of each data type
    # print('\n\nData types count:')
    # print(df.dtypes.value_counts())

    # # Get summary statistics, including object types
    # print('\n\nDescribe the DataFrame (including categorical data):')
    # print(df.describe(include='O'))

    # # Print the number of duplicate rows in the DataFrame
    # display(f'\n\nNumber of duplicate rows: {df.duplicated().sum():,}')

    # # Display the count of missing values for each column
    # print('\n\nMissing values per column:')
    # display(pd.DataFrame(df.isna().sum(), columns=['Missing Values']))

# %%
# [os.listdir("../data/raw_data")]
files = [f for f in os.listdir("../data/raw_data") if f.endswith('.csv')]
files
# Out:
# ['medicine_dataset.csv',
#  'PubChemLite_31Oct2020_exposomics.csv',
#  'Allergen_Status_of_Food_Products.csv',
#  'drug_relation_dfe.csv',
#  'Medicine.csv']

# %%
medicine_dataset = pd.read_csv(os.path.join(base_path, 'medicine_dataset.csv'), index_col='id')
medicine_dataset
# Out:
# /var/folders/qx/yrwdfm5j0jz1gmhp0x2tvjy80000gn/T/ipykernel_16828/2039300471.py:1: DtypeWarning: Columns (42,43,44,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   medicine_dataset = pd.read_csv(os.path.join(base_path, 'medicine_dataset.csv'), index_col='id')
#                                         name  \
# id
# 1                   augmentin 625 duo tablet
# 2                        azithral 500 tablet
# 3                           ascoril ls syrup
# 4                       allegra 120mg tablet
# 5                             avil 25 tablet
# ...                                      ...
# 248214  zestrain 100mg/325mg/250mg tablet mr
# 248215              zoxinace 200mg tablet sr
# 248216                     zivex 25mg tablet
# 248217               zi fast 500mg injection
# 248218             zyvocol 1% dusting powder
#
#                                 substitute0             substitute1  \
# id
# ...

# %%
eda_pipeline(medicine_dataset)
# Out:
# Columns:
# Index(['name', 'substitute0', 'substitute1', 'substitute2', 'substitute3',
#        'substitute4', 'sideEffect0', 'sideEffect1', 'sideEffect2',
#        'sideEffect3', 'sideEffect4', 'sideEffect5', 'sideEffect6',
#        'sideEffect7', 'sideEffect8', 'sideEffect9', 'sideEffect10',
#        'sideEffect11', 'sideEffect12', 'sideEffect13', 'sideEffect14',
#        'sideEffect15', 'sideEffect16', 'sideEffect17', 'sideEffect18',
#        'sideEffect19', 'sideEffect20', 'sideEffect21', 'sideEffect22',
#        'sideEffect23', 'sideEffect24', 'sideEffect25', 'sideEffect26',
#        'sideEffect27', 'sideEffect28', 'sideEffect29', 'sideEffect30',
#        'sideEffect31', 'sideEffect32', 'sideEffect33', 'sideEffect34',
#        'sideEffect35', 'sideEffect36', 'sideEffect37', 'sideEffect38',
#        'sideEffect39', 'sideEffect40', 'sideEffect41', 'use0', 'use1', 'use2',
#        'use3', 'use4', 'Chemical Class', 'Habit Forming', 'Therapeutic Class',
#        'Action Class'],
# ...
