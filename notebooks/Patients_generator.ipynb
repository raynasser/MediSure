# %% [markdown]
# # Here we are using the model 'Synthea' to generate patients as a DataSet so we can work with it

# %%
import pandas as pd
import numpy as np
import datetime as dt
from datetime import date

# %% [markdown]
# ## Selecting the tables that we want to work on.
#
# ## which is:
# ### - allergies
# ### - medications
# ### - patients

# %%
df_allergies = pd.read_csv("/Users/aziz/code/raynasser/MediSure/MediSure/generative_models/Synthea/output/csv/allergies.csv")
df_medications = pd.read_csv("/Users/aziz/code/raynasser/MediSure/MediSure/generative_models/Synthea/output/csv/medications.csv")
df_patients = pd.read_csv("/Users/aziz/code/raynasser/MediSure/MediSure/generative_models/Synthea/output/csv/patients.csv")

# %% [markdown]
#   ##     Adding the 'AGE' column from the 'BIRTHDAY' column.

# %%
df_patients["BIRTHDATE"] = pd.to_datetime(df_patients['BIRTHDATE'])
df_patients['today'] = pd.to_datetime(dt.date.today())
df_patients['Age'] = (df_patients['today'] - df_patients['BIRTHDATE']).dt.days/365
df_patients['Age'] = df_patients['Age'].apply(lambda x: int(x))

df_patients.drop(columns={'today'}, inplace=True)

# %% [markdown]
# ## renaming Id to PATIENT, in patients table

# %%
df_patients.rename(columns={'Id': 'PATIENT'}, inplace=True)

# %% [markdown]
# ## Drop useless features from the columns

# %%
df_allergies = df_allergies.drop(columns=['START','STOP','ENCOUNTER','REACTION1','DESCRIPTION1','SEVERITY1','REACTION2','DESCRIPTION2','SEVERITY2'])
df_medications.drop(columns = ['REASONDESCRIPTION','CODE','START', 'STOP','PAYER','BASE_COST', 'PAYER_COVERAGE', 'DISPENSES', 'TOTALCOST', 'REASONCODE'], inplace = True)
df_patients.drop(columns = ['BIRTHDATE','DEATHDATE','SSN','DRIVERS','PASSPORT','PREFIX','SUFFIX','MAIDEN','MARITAL','RACE',
       'ETHNICITY','FIPS', 'ZIP', 'LAT', 'LON', 'HEALTHCARE_EXPENSES',
       'HEALTHCARE_COVERAGE', 'INCOME','STATE','BIRTHPLACE','STATE','COUNTY'], inplace = True)

# %% [markdown]
# ### grouping the allergies table by patient column and separating each allergy for a specefic patient in a new column

# %%
# Group by 'PATIENT' and create a list of allergies for each patient
patient_allergies = df_allergies.groupby('PATIENT')['DESCRIPTION'].apply(list).reset_index()

# Expand the list of allergies into separate columns
patient_allergies_expanded = pd.DataFrame(patient_allergies['DESCRIPTION'].tolist(), index=patient_allergies['PATIENT']).reset_index()

# Dynamically rename columns based on the maximum number of allergies
max_allergies = patient_allergies_expanded.shape[1] - 1  # Subtract 1 for the 'PATIENT' column
new_column_names = ['PATIENT'] + [f'Allergy {i+1}' for i in range(max_allergies)]
patient_allergies_expanded.columns = new_column_names

# %%
patient_allergies_expanded.drop(columns=['Allergy 1'], inplace=True)

# Reassign column names based on the new number of allergies
# Get the number of remaining allergy columns
max_allergies = patient_allergies_expanded.shape[1] - 1  # Subtract 1 for the 'PATIENT' column

# Create new column names
new_column_names = ['PATIENT'] + [f'Allergy {i+1}' for i in range(max_allergies)]
patient_allergies_expanded.columns = new_column_names

# %% [markdown]
# ### grouping the medication table by patient column and separating each medication for a specefic patient in a new column

# %%
# Group by 'PATIENT' and create a list of medications for each patient
patient_medications = df_medications.groupby('PATIENT')['DESCRIPTION'].apply(list).reset_index()

# Find the maximum number of medications any single patient has
max_medications = patient_medications['DESCRIPTION'].apply(len).max()

# Expand the list of medications into separate columns
patient_medications_expanded = pd.DataFrame(patient_medications['DESCRIPTION'].tolist(), index=patient_medications['PATIENT']).reset_index()

# Dynamically rename columns based on the number of medications
new_column_names = ['PATIENT'] + [f'Medication {i+1}' for i in range(max_medications)]
patient_medications_expanded.columns = new_column_names

# %% [markdown]
# ### saving the medications in a csv file

# %%
medication_columns = [col for col in patient_medications_expanded.columns if col.startswith('Medication')]

# Concatenate all medications into a single list and drop duplicates
unique_medications = pd.unique(patient_medications_expanded[medication_columns].values.ravel('K'))

# Convert the result into a list (optional)
unique_medications_list = unique_medications.tolist()

# Display the unique medications
print(unique_medications_list)

medications_df = pd.DataFrame(unique_medications_list, columns=['Unique Medications'])

# Save the DataFrame to a CSV file
medications_df.to_csv('unique_medications.csv', index=False)
# Out:
# ['Naproxen sodium 220 MG Oral Tablet', 'Vitamin B12 5 MG/ML Injectable Solution', 'Chlorpheniramine Maleate 2 MG/ML Oral Solution', 'sodium fluoride 0.0272 MG/MG Oral Gel', 'Simvastatin 10 MG Oral Tablet', 'Hydrochlorothiazide 25 MG Oral Tablet', 'Ibuprofen 100 MG Oral Tablet', 'insulin isophane  human 70 UNT/ML / insulin  regular  human 30 UNT/ML Injectable Suspension [Humulin]', 'Acetaminophen 325 MG Oral Tablet', 'Loratadine 5 MG Chewable Tablet', 'diphenhydrAMINE Hydrochloride 25 MG Oral Tablet', 'Hydrocortisone 10 MG/ML Topical Cream', 'cetirizine hydrochloride 5 MG Oral Tablet', '1 ML medroxyprogesterone acetate 150 MG/ML Injection', 'Natazia 28 Day Pack', 'Amoxicillin 250 MG / Clavulanate 125 MG Oral Tablet', 'Kyleena 19.5 MG Intrauterine System', 'ferrous sulfate 325 MG Oral Tablet', 'Clopidogrel 75 MG Oral Tablet', 'Alteplase 100 MG Injection', 'carbamazepine 20 MG/ML Oral Suspension [Tegretol]', 'aspirin 81 MG Oral Tablet', 'lisinopril 10 MG Oral Tablet', 'atomoxetine 100 MG Oral Capsule', 'Trinessa 28 Day Pack', '120 ACTUAT fluticasone propionate 0.044 MG/ACTUAT Metered Dose Inhaler [Flovent]', 'Yaz 28 Day Pack', 'Ibuprofen 400 MG Oral Tablet [Ibu]', 'Fexofenadine hydrochloride 30 MG Oral Tablet', 'budesonide 0.125 MG/ML Inhalation Suspension', 'Amoxicillin 500 MG Oral Tablet', 'Acetaminophen 300 MG / Codeine Phosphate 15 MG Oral Tablet', '72 HR Fentanyl 0.025 MG/HR Transdermal System', 'Acetaminophen 21.7 MG/ML / Dextromethorphan Hydrobromide 1 MG/ML / doxylamine succinate 0.417 MG/ML Oral Solution', 'Seasonique 91 Day Pack', 'Acetaminophen 300 MG / Hydrocodone Bitartrate 5 MG Oral Tablet', 'amLODIPine 2.5 MG Oral Tablet', 'Penicillin V Potassium 250 MG Oral Tablet', 'FLUoxetine 20 MG Oral Capsule', 'Levora 0.15/30 28 Day Pack', 'Camila 28 Day Pack', 'Mirena 52 MG Intrauterine System', 'NuvaRing 0.12/0.015 MG per 24HR 21 Day Vaginal System', 'Astemizole 10 MG Oral Tablet', 'Errin 28 Day Pack', 'Acetaminophen 160 MG Chewable Tablet', 'Acetaminophen 325 MG / Oxycodone Hydrochloride 10 MG Oral Tablet [Percocet]', '1 ML medroxyPROGESTERone acetate 150 MG/ML Injection', 'Diazepam 5 MG Oral Tablet', 'Simvastatin 20 MG Oral Tablet', 'Etonogestrel 68 MG Drug Implant', 'nicotine 7 MG/Day 24HR Transdermal System', 'NDA020983 200 ACTUAT albuterol 0.09 MG/ACTUAT Metered Dose Inhaler [Ventolin]', 'Liletta 52 MG Intrauterine System', 'Mestranol / Norethynodrel', 'Acetaminophen 325 MG Oral Tablet [Tylenol]', 'Jolivette 28 Day Pack', 'Abuse-Deterrent 12 HR Oxycodone Hydrochloride 10 MG Extended Release Oral Tablet [Oxycontin]', 'Ibuprofen 200 MG Oral Tablet', 'Nitroglycerin 0.4 MG/ACTUAT Mucosal Spray', 'Levothyroxine Sodium 0.075 MG Oral Tablet', 'cephalexin 500 MG Oral Tablet', 'clonazePAM 0.25 MG Oral Tablet', 'Amoxicillin 250 MG Oral Capsule', '24 HR Metformin hydrochloride 500 MG Extended Release Oral Tablet', 'albuterol 5 MG/ML Inhalation Solution', 'Acetaminophen 325 MG / oxyCODONE Hydrochloride 5 MG Oral Tablet', 'Alendronic acid 10 MG Oral Tablet', '168 HR Ethinyl Estradiol 0.00146 MG/HR / norelgestromin 0.00625 MG/HR Transdermal System', 'Acetaminophen 325 MG / HYDROcodone Bitartrate 7.5 MG Oral Tablet', '120 ACTUAT fluticasone propionate 0.11 MG/ACTUAT Metered Dose Inhaler [Flovent]', 'efavirenz 600 MG / emtricitabine 200 MG / tenofovir disoproxil fumarate 300 MG Oral Tablet', 'Penicillin V Potassium 500 MG Oral Tablet', 'Terfenadine 60 MG Oral Tablet', 'Abuse-Deterrent 12 HR Oxycodone Hydrochloride 15 MG Extended Release Oral Tablet', 'Colchicine 0.6 MG Oral Tablet', '24 HR metoprolol succinate 100 MG Extended Release Oral Tablet', 'Cefuroxime 250 MG Oral Tablet', 'tramadol hydrochloride 50 MG Oral Tablet', 'doxycycline hyclate 100 MG', 'budesonide 0.25 MG/ML Inhalation Suspension', 'Furosemide 40 MG Oral Tablet', 'glycopyrrolate 1.5 MG Oral Tablet [Glycate]', 'predniSONE 5 MG Oral Tablet', '24 HR metoprolol succinate 50 MG Extended Release Oral Tablet', 'Norinyl 1+50 28 Day Pack', 'Penicillin G 375 MG/ML Injectable So ...

# %% [markdown]
# # merging the tables into one table to have a complete profile of the patient

# %%
# Merge df_patients with patient_allergies_expanded
merged_allergies = pd.merge(df_patients, patient_allergies_expanded, on='PATIENT', how='left')

# Merge the result with patient_medications_expanded
final_merged = pd.merge(merged_allergies, patient_medications_expanded, on='PATIENT', how='left')

# %% [markdown]
# ## droping any patient that doesnt take allergy nor medication

# %%
# Drop patients with no allergies and no medications
# Get the list of allergy and medication columns
allergy_columns = [f'Allergy {i}' for i in range(1, 13)]  # Assuming there are 12 allergy columns
medication_columns = [f'Medication {i}' for i in range(1, 2020)]  # Assuming there are 2019 medication columns

# Filter the DataFrame to keep only patients with at least one allergy or medication
profiles = final_merged.dropna(subset=allergy_columns + medication_columns, how='all')

# %% [markdown]
# # free testing 👇🏻

# %%
profiles.iloc[11][27]

# profiles.columns[23]
# Out:
# /var/folders/lx/dlcmglnd5514lttspw0c50x80000gp/T/ipykernel_15988/2091724463.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   profiles.iloc[11][27]
# 'Simvastatin 10 MG Oral Tablet'

# %%
profiles.to_csv('profiles.csv', index=False)

# %%
patient_medications_expanded[patient_medications_expanded['Medication 2019'] == 'amLODIPine 2.5 MG Oral Tablet']
# Out:
#                                    PATIENT  \
# 1810  ce452a7b-2543-e768-c6bb-cabddb6665a3
#
#                                            Medication 1  \
# 1810  24 HR metoprolol succinate 100 MG Extended Rel...
#
#                                    Medication 2  \
# 1810  Nitroglycerin 0.4 MG/ACTUAT Mucosal Spray
#
#                                            Medication 3  \
# 1810  insulin isophane  human 70 UNT/ML / insulin  r...
#
#                                Medication 4  \
# 1810  Hydrochlorothiazide 25 MG Oral Tablet
#
#                                            Medication 5  \
# 1810  24 HR tacrolimus 1 MG Extended Release Oral Ta...
#
#                       Medication 6                   Medication 7  \
# 1810  lisinopril 10 MG Oral Tablet  amLODIPine 2.5 MG Oral Tablet
#
#                                            Medication 8  \
# 1810  insulin isophane  human 70 UNT/ML / insulin  r...
#
#                                Medication 9  ...  \
# 1810  Hydrochlorothiazide 25 MG Oral Tablet  ...
#
#                                         Medication 2010  \
# 1810  insulin isophane  human 70 UNT/ML / insulin  r...
#
#                             Medication 2011  \
# 1810  Hydrochlorothiazide 25 MG Oral Tablet
#
#                                         Medication 2012  \
# 1810  24 HR tacrolimus 1 MG Extended Release Oral Ta...
#
#                    Medication 2013                Medication 2014  \
# 1810  lisinopril 10 MG Oral Tablet  amLODIPine 2.5 MG Oral Tablet
#
#                                         Medication 2015  \
# 1810  insulin isophane  human 70 UNT/ML / insulin  r...
#
#                             Medication 2016  \
# 1810  Hydrochlorothiazide 25 MG Oral Tablet
#
#                                         Medication 2017  \
# 1810  24 HR tacrolimus 1 MG Extended Release Oral Ta...
#
#                    Medication 2018                Medication 2019
# 1810  lisinopril 10 MG Oral Tablet  amLODIPine 2.5 MG Oral Tablet
#
# [1 rows x 2020 columns]

# %%
df_patients
# Out:
#                                         Id         FIRST        MIDDLE  \
# 0     a3701e6e-6d11-32cd-a4e6-8515efcb34f2      Micah422      Kenda873
# 1     e7d7cef3-0f41-afc5-0c72-2da66c33cdc5        Juan88     Lucien408
# 2     2a91b214-afb8-339f-2bc5-b80b679e5fd2      Irwin931      Graig740
# 3     d8f6e82b-e0c9-46bb-a3f0-d1e9d4da045d       Jack927           NaN
# 4     3af2a564-3bfd-7c9a-3d44-575e6e0cf3b3       Yuri475  Armandina361
# ...                                    ...           ...           ...
# 2338  a3bb83be-b30f-8697-b4c7-fb190c597464    Melissa844    Lasonya941
# 2339  f11123a1-7513-4826-bea5-441ede68fe92     Garret233    Gilbert263
# 2340  c9b1bda9-3c61-8618-c55a-4565c4ff9469  Kassandra256     Aletha771
# 2341  988452fe-6908-ad38-8e19-302a3bb6c72c     Wesley533    Modesta635
# 2342  136d0544-5b8e-6407-fcdb-451dbcbcc840      Vicki422     Shelba765
#
#               LAST GENDER                        ADDRESS            CITY  Age
# 0     Gutkowski940      F       559 Johnston Bay Unit 85          Boston   12
# 1       Gutmann970      M                 517 Mante Mews          Newton   39
# 2         Sipes176      M               962 Crona Course          Boston   51
# 3       Collins926      M          268 Pacocha Esplanade         Reading   52
# 4        Nienow652      F             303 Dietrich Ville         Belmont    8
# ...            ...    ...                            ...             ...  ...
# 2338      Kunze215      F             900 Trantow Course          Lowell  110
# 2339        Purdy2      M  329 O'Conner Junction Unit 54  North Plymouth   47
# 2340    Roberts511      F              562 Schneider Way          Lowell  110
# 2341    Smitham825      F              485 Lebsack Track       Haverhill   84
# 2342      Bruen238      F              980 Effertz Manor          Lowell  110
#
# [2343 rows x 8 columns]

# %%
profiles
# Out:
#                                    PATIENT         FIRST        MIDDLE  \
# 0     a3701e6e-6d11-32cd-a4e6-8515efcb34f2      Micah422      Kenda873
# 1     e7d7cef3-0f41-afc5-0c72-2da66c33cdc5        Juan88     Lucien408
# 2     2a91b214-afb8-339f-2bc5-b80b679e5fd2      Irwin931      Graig740
# 3     d8f6e82b-e0c9-46bb-a3f0-d1e9d4da045d       Jack927           NaN
# 4     3af2a564-3bfd-7c9a-3d44-575e6e0cf3b3       Yuri475  Armandina361
# ...                                    ...           ...           ...
# 2338  a3bb83be-b30f-8697-b4c7-fb190c597464    Melissa844    Lasonya941
# 2339  f11123a1-7513-4826-bea5-441ede68fe92     Garret233    Gilbert263
# 2340  c9b1bda9-3c61-8618-c55a-4565c4ff9469  Kassandra256     Aletha771
# 2341  988452fe-6908-ad38-8e19-302a3bb6c72c     Wesley533    Modesta635
# 2342  136d0544-5b8e-6407-fcdb-451dbcbcc840      Vicki422     Shelba765
#
#               LAST GENDER                        ADDRESS            CITY  Age  \
# 0     Gutkowski940      F       559 Johnston Bay Unit 85          Boston   12
# 1       Gutmann970      M                 517 Mante Mews          Newton   39
# 2         Sipes176      M               962 Crona Course          Boston   51
# 3       Collins926      M          268 Pacocha Esplanade         Reading   52
# 4        Nienow652      F             303 Dietrich Ville         Belmont    8
# ...            ...    ...                            ...             ...  ...
# 2338      Kunze215      F             900 Trantow Course          Lowell  110
# 2339        Purdy2      M  329 O'Conner Junction Unit 54  North Plymouth   47
# 2340    Roberts511      F              562 Schneider Way          Lowell  110
# 2341    Smitham825      F              485 Lebsack Track       Haverhill   84
# 2342      Bruen238      F              980 Effertz Manor          Lowell  110
#
#                       Allergy 1                        Allergy 2  ...  \
# 0                           NaN                              NaN  ...
# 1                           NaN                              NaN  ...
# 2     Animal dander (substance)  Sulfamethoxazole / Trimethoprim  ...
# 3                           NaN                              NaN  ...
# 4               Mold (organism)        Animal dander (substance)  ...
# ...                         ...                              ...  ...
# 2338                        NaN                              NaN  ...
# 2339                        NaN                              NaN  ...
# 2340                        NaN                              NaN  ...
# 2341                        NaN                              NaN  ...
# 2342                        NaN                              NaN  ...
#
#      Medication 2010 Medication 2011 Medication 2012 Medication 2013  \
# 0               None            None            None            None
# 1               None            None            None            None
# 2               None            None            None            None
# 3               None            None            None            None
# 4               None            None            None            None
# ...              ...             ...             ...             ...
# 2338            None            None            None            None
# 2339            None            None            None            None
# 2340            None            None            None            None
# 2341            None            None            None            None
# 2342            None            None            None            None
#
#      Medication 2014 Medication 2015 Medication 2016 Medication 2017  \
# 0               None            None            None            None
# 1               None            None            None            None
# 2               None            None            None            None
# 3               None            None            None            None
# 4               None            None            None            None
# ...              ...             ...             ...             ...
# 2338            None            None            None            None
# 2339            None            None            None            None
# 2340            None            None            None            None
# 2341            None            None            None            None
# 2342            None            None            None            None
#
#      Medication 2018 Medication 2019
# 0               None            None
# 1               None            None
# 2               None            None
# 3               None            None
# 4               None            None
# ...              ...             ...
# 2338            None            None
# 2339            None            None
# 2340            None            None
# 2341            None            None
# 2342            None            None
#
# [2294 rows x 2039 columns]
